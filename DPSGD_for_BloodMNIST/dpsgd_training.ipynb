# %%
# To config Google Colab

# Install MedMNIST and privacy tools
# !pip install medmnist fire
# !pip install opacus==1.4.0


# Verify
# import torch
# print(f"PyTorch version: {torch.__version__}")
# print(f"CUDA available: {torch.cuda.is_available()}")
# print(f"CUDA version: {torch.version.cuda if torch.cuda.is_available() else 'Not available'}")

# %%
from utility import set_seed, get_datasets, get_dataloaders, get_data_info, scores
from model import get_model, get_optimizer, get_loss_function

# %%
from tqdm import tqdm
import numpy as np
import torch
import torch.nn as nn
import torch.optim as optim
import torch.utils.data as data

import glob
import medmnist
from medmnist import INFO, Evaluator
import pandas as pd
import os
import matplotlib.pyplot as plt
# %config InlineBackend.figure_formats=['svg']
import time

from opacus import PrivacyEngine

# %% [markdown]
# ## Main Training Parameters

# %%
data_flag = 'bloodmnist'
info = get_data_info(data_flag)

# Main training parameters
NUM_EPOCHS = 100
BATCH_SIZE = 128
LR = 0.001
n_channels = info['n_channels']
n_classes = len(info['label'])
K_max = 3  # Number of initializations for averaging results
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Early stopping parameters
PATIENCE = 10  # number of epochs we wait for improvement
MIN_DELTA = 0.01  # minimum improvement
MIN_EPOCHS = 40  # minimum number of epochs before early stopping can be triggered, must be less than NUM_EPOCHS
if MIN_EPOCHS >= NUM_EPOCHS:
    raise ValueError("MIN_EPOCHS must be less than NUM_EPOCHS for early stopping to work.")

# Privacy Parameters
C = 0.1259
EPSILON = 2
DELTA = 7*10**(-9)

# %% [markdown]
# ## Preprocess and data loading

# %%
train_dataset, val_dataset, test_dataset = get_datasets(data_flag)
train_loader, val_loader, test_loader = get_dataloaders(train_dataset, val_dataset, test_dataset, batch_size=BATCH_SIZE)
train_loader_at_eval = data.DataLoader(dataset=train_dataset, batch_size=2*BATCH_SIZE, shuffle=False)
val_loader_at_eval = data.DataLoader(dataset=val_dataset, batch_size=2*BATCH_SIZE, shuffle=False)

# %%
## Model
criterion = get_loss_function(info['task'])

# Define the path to save the models
MODEL_SAVE_PATH = 'final_models/weights'

# %%
loss_curve_train = []
loss_curve_val = []

auc_curve_train = []
auc_curve_val = []

# only for 1 initit of weights
acc_curve_train = []
acc_curve_val = []

# K is the number of attempts to average the final accuracy and time for training

# To track metrics
best_models = []  # To store file paths of best models
early_stop_epochs = []  # To track when each run stopped
early_stop_times = []  # To track training time until early stopping
av_epoch_time = []


for K in range(3):

    # need to init model weights
    model = get_model(n_channels, n_classes)
    optimizer = get_optimizer(model, lr=LR)
    criterion = get_loss_function(info['task'])

    # Initialize PrivacyEngine
    privacy_engine = PrivacyEngine() # secure_mode=True

    model, optimizer, train_loader = privacy_engine.make_private_with_epsilon(
        module=model,
        optimizer=optimizer,
        data_loader=train_loader,
        target_epsilon=EPSILON, # Noise parameter
        target_delta = DELTA,
        epochs = NUM_EPOCHS,
        max_grad_norm=C,    # Gradient clipping norm
        loss_reduction = 'mean', #Indicates if the loss reduction (for aggregating the gradients) is a sum or a mean operation.
    )


    # Early stopping variables
    best_val_metric = 0  # For ACC (higher is better)
    best_epoch = 0
    no_improve_count = 0
    best_model_path = None

    # Time tracking
    total_time = 0
    epoch_times = []

    # For tracking metrics
    loss_curve_train = []
    loss_curve_val = []


    for epoch in range(NUM_EPOCHS):
        train_loss = 0.0
        train_batches = 0

        # Training phase
        start_epoch_time = time.perf_counter()

        model.train()
        for inputs, targets in tqdm(train_loader):

            inputs = inputs.to(device)
            targets = targets.to(device)

            optimizer.zero_grad()
            outputs = model(inputs)


            # can be used for other 2D datasets
            if info['task'] == 'multi-label, binary-class':
                targets = targets.to(torch.float32)
                loss = criterion(outputs, targets)
            else:
                targets = targets.squeeze().long()
                loss = criterion(outputs, targets)

            loss.backward()
            optimizer.step()

            train_loss += loss.item()
            train_batches += 1

        avg_train_loss = train_loss / train_batches if train_batches > 0 else 0
        loss_curve_train.append(avg_train_loss)

        # Validation
        model.eval()
        val_loss = 0.0
        val_batches = 0

        with torch.no_grad():

            for val_inputs, val_targets in val_loader:
                val_inputs = val_inputs.to(device)
                val_targets = val_targets.to(device)

                val_outputs = model(val_inputs)
                if info['task'] == 'multi-label, binary-class':
                    val_targets = val_targets.to(torch.float32)
                    v_loss = criterion(val_outputs, val_targets)
                else:
                    val_targets = val_targets.squeeze().long()
                    v_loss = criterion(val_outputs, val_targets)

                val_loss += v_loss.item()
                val_batches += 1

        avg_val_loss = val_loss / val_batches if val_batches > 0 else 0
        loss_curve_val.append(avg_val_loss)

        # ---- Calculate validation ACC for early stopping ----
        metric_val = scores('val', model, info, data_flag, train_loader_at_eval, val_loader_at_eval, test_loader)

        current_metric = metric_val.ACC

        end_epoch_time = time.perf_counter()
        epoch_time = end_epoch_time - start_epoch_time
        epoch_times.append(epoch_time)
        total_time += epoch_time
        av_epoch_time.append(epoch_time)

        # we save acc and auc curves only for 1 initialization as they don't significantly differ + evaluation takes time
        if K == 0:
            metric_train = scores('train', model, info, data_flag, train_loader_at_eval, val_loader_at_eval, test_loader)

            auc_curve_train.append(metric_train.AUC)
            acc_curve_train.append(metric_train.ACC)

            metric_val = scores('val', model, info, data_flag, train_loader_at_eval, val_loader_at_eval, test_loader)
            auc_curve_val.append(metric_val.AUC)
            acc_curve_val.append(metric_val.ACC)

        print(f"Epoch {epoch+1} train loss: {avg_train_loss:.4f}, val loss: {avg_val_loss:.4f}")
        print(f"Epoch {epoch+1} training time: {epoch_time:.2f} seconds")

        epsilon = privacy_engine.get_epsilon(DELTA)
        print(f"Privacy cost: (ε = {epsilon:.2f}, δ = {DELTA})")

        # Early stopping check
        if epoch > MIN_EPOCHS and current_metric > best_val_metric + MIN_DELTA:
            print(f"Validation metric improved from {best_val_metric:.4f} to {current_metric:.4f}")
            best_val_metric = current_metric
            best_epoch = epoch
            no_improve_count = 0

            # Save best model with updated path
            model_filename = f'model_init_{K}_best_epoch_{epoch}_auc_{metric_val.AUC:.4f}_acc_{metric_val.ACC:.4f}.pth'
            model_path = os.path.join(MODEL_SAVE_PATH, model_filename)

            # Check if model has the _module attribute (from privacy engine)
            if hasattr(model, '_module'):
                torch.save(model._module.state_dict(), model_path)
            else:
                torch.save(model.state_dict(), model_path)

            best_model_path = model_path
            print(f"Saved best model to {model_path}")
        else:
            if epoch > MIN_EPOCHS:
                no_improve_count += 1
                print(f"No improvement for {no_improve_count} epochs")

        # Check if we should stop
        if epoch > MIN_EPOCHS and no_improve_count >= PATIENCE:
            print(f"Early stopping at epoch {epoch+1}")
            break

    # Training phase finishes here
    early_stop_epochs.append(best_epoch + 1)  # +1 for 1-based indexing
    early_stop_times.append(total_time)
    best_models.append(best_model_path)

    # epsilon = accountant.get_epsilon(delta=DELTA)
    # print(f"Epsilon: {epsilon}")


    print("--------------------------------")
    print(f"Instance {K}")
    print(f"Best epoch: {best_epoch + 1}")
    print(f"Best validation ACC: {best_val_metric:.4f}")
    print(f"Training time until best model: {sum(epoch_times[:best_epoch+1]):.2f} seconds")
    print(f"Total training time: {total_time:.2f} seconds")
# Out:
# Using device: cuda
# /usr/local/lib/python3.11/dist-packages/opacus/privacy_engine.py:142: UserWarning: Secure RNG turned off. This is perfectly fine for experimentation as it allows for much faster training performance, but remember to turn it on and retrain one last time before production with ``secure_mode`` turned on.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/opacus/accountants/analysis/rdp.py:332: UserWarning: Optimal order is the largest alpha. Please consider expanding the range of alphas to get a tighter privacy bound.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/opacus/accountants/analysis/prv/prvs.py:50: RuntimeWarning: invalid value encountered in log
#   z = np.log((np.exp(t) + q - 1) / q)
#   0%|          | 0/94 [00:00<?, ?it/s]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1830: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)
# 100%|██████████| 94/94 [00:05<00:00, 18.10it/s]
# /usr/local/lib/python3.11/dist-packages/opacus/accountants/analysis/rdp.py:332: UserWarning: Optimal order is the largest alpha. Please consider expanding the range of alphas to get a tighter privacy bound.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/opacus/accountants/analysis/prv/prvs.py:50: RuntimeWarning: invalid value encountered in log
#   z = np.log((np.exp(t) + q - 1) / q)
# Epoch 1 train loss: 1.9597, val loss: 1.8242
# Epoch 1 training time: 5.99 seconds
# Privacy cost: (ε = 0.20, δ = 7.000000000000001e-09)
#   0%|          | 0/94 [00:00<?, ?it/s]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1830: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)
# 100%|██████████| 94/94 [00:04<00:00, 20.07it/s]
# /usr/local/lib/python3.11/dist-packages/opacus/accountants/analysis/rdp.py:332: UserWarning: Optimal order is the largest alpha. Please consider expanding the range of alphas to get a tighter privacy bound.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/opacus/accountants/analysis/prv/prvs.py:50: RuntimeWarning: invalid value encountered in log
#   z = np.log((np.exp(t) + q - 1) / q)
# Epoch 2 train loss: 1.6685, val loss: 1.5302
# Epoch 2 training time: 5.48 seconds
# Privacy cost: (ε = 0.28, δ = 7.000000000000001e-09)
#   0%|          | 0/94 [00:00<?, ?it/s]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1830: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)
# 100%|██████████| 94/94 [00:05<00:00, 16.44it/s]
# /usr/local/lib/python3.11/dist-packages/opacus/accountants/analysis/rdp.py:332: UserWarning: Optimal order is the largest alpha. Please consider expanding the range of alphas to get a tighter privacy bound.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/opacus/accountants/analysis/prv/prvs.py:50: RuntimeWarning: invalid value encountered in log
#   z = np.log((np.exp(t) + q - 1) / q)
# Epoch 3 train loss: 1.4682, val loss: 1.4225
# Epoch 3 training time: 6.52 seconds
# Privacy cost: (ε = 0.34, δ = 7.000000000000001e-09)
#   0%|          | 0/94 [00:00<?, ?it/s]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1830: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)
# 100%|██████████| 94/94 [00:04<00:00, 20.74it/s]
# /usr/local/lib/python3.11/dist-packages/opacus/accountants/analysis/rdp.py:332: UserWarning: Optimal order is the largest alpha. Please consider expanding the range of alphas to get a tighter privacy bound.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/opacus/accountants/analysis/prv/prvs.py:50: RuntimeWarning: invalid value encountered in log
#   z = np.log((np.exp(t) + q - 1) / q)
# Epoch 4 train loss: 1.3454, val loss: 1.2292
# Epoch 4 training time: 5.61 seconds
# Privacy cost: (ε = 0.39, δ = 7.000000000000001e-09)
#   0%|          | 0/94 [00:00<?, ?it/s]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1830: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)
# 100%|██████████| 94/94 [00:04<00:00, 20.23it/s]
# /usr/local/lib/python3.11/dist-packages/opacus/accountants/analysis/rdp.py:332: UserWarning: Optimal order is the largest alpha. Please consider expanding the range of alphas to get a tighter privacy bound.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/opacus/accountants/analysis/prv/prvs.py:50: RuntimeWarning: invalid value encountered in log
#   z = np.log((np.exp(t) + q - 1) / q)
# Epoch 5 train loss: 1.1649, val loss: 1.0509
# Epoch 5 training time: 5.43 seconds
# Privacy cost: (ε = 0.43, δ = 7.000000000000001e-09)
#   0%|          | 0/94 [00:00<?, ?it/s]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1830: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)
# 100%|██████████| 94/94 [00:06<00:00, 14.79it/s]
# /usr/local/lib/python3.11/dist-packages/opacus/accountants/analysis/rdp.py:332: UserWarning: Optimal order is the largest alpha. Please consider expanding the range of alphas to get a tighter privacy bound.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/opacus/accountants/analysis/prv/prvs.py:50: RuntimeWarning: invalid value encountered in log
#   z = np.log((np.exp(t) + q - 1) / q)
# Epoch 6 train loss: 1.0150, val loss: 0.9211
# Epoch 6 training time: 8.22 seconds
# Privacy cost: (ε = 0.47, δ = 7.000000000000001e-09)
#   0%|          | 0/94 [00:00<?, ?it/s]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1830: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)
# 100%|██████████| 94/94 [00:05<00:00, 16.75it/s]
# /usr/local/lib/python3.11/dist-packages/opacus/accountants/analysis/rdp.py:332: UserWarning: Optimal order is the largest alpha. Please consider expanding the range of alphas to get a tighter privacy bound.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/opacus/accountants/analysis/prv/prvs.py:50: RuntimeWarning: invalid value encountered in log
#   z = np.log((np.exp(t) + q - 1) / q)
# Epoch 7 train loss: 0.9348, val loss: 0.8655
# Epoch 7 training time: 6.36 seconds
# Privacy cost: (ε = 0.51, δ = 7.000000000000001e-09)
#   0%|          | 0/94 [00:00<?, ?it/s]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1830: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)
# 100%|██████████| 94/94 [00:04<00:00, 20.01it/s]
# /usr/local/lib/python3.11/dist-packages/opacus/accountants/analysis/rdp.py:332: UserWarning: Optimal order is the largest alpha. Please consider expanding the range of alphas to get a tighter privacy bound.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/opacus/accountants/analysis/prv/prvs.py:50: RuntimeWarning: invalid value encountered in log
#   z = np.log((np.exp(t) + q - 1) / q)
# Epoch 8 train loss: 0.8841, val loss: 0.8166
# Epoch 8 training time: 5.71 seconds
# Privacy cost: (ε = 0.55, δ = 7.000000000000001e-09)
#   0%|          | 0/94 [00:00<?, ?it/s]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1830: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)
# 100%|██████████| 94/94 [00:04<00:00, 20.05it/s]
# /usr/local/lib/python3.11/dist-packages/opacus/accountants/analysis/rdp.py:332: UserWarning: Optimal order is the largest alpha. Please consider expanding the range of alphas to get a tighter privacy bound.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/opacus/accountants/analysis/prv/prvs.py:50: RuntimeWarning: invalid value encountered in log
#   z = np.log((np.exp(t) + q - 1) / q)
# Epoch 9 train loss: 0.8757, val loss: 0.7978
# Epoch 9 training time: 5.52 seconds
# Privacy cost: (ε = 0.58, δ = 7.000000000000001e-09)
#   0%|          | 0/94 [00:00<?, ?it/s]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1830: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)
# 100%|██████████| 94/94 [00:05<00:00, 16.83it/s]
# /usr/local/lib/python3.11/dist-packages/opacus/accountants/analysis/rdp.py:332: UserWarning: Optimal order is the largest alpha. Please consider expanding the range of alphas to get a tighter privacy bound.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/opacus/accountants/analysis/prv/prvs.py:50: RuntimeWarning: invalid value encountered in log
#   z = np.log((np.exp(t) + q - 1) / q)
# Epoch 10 train loss: 0.8469, val loss: 0.7718
# Epoch 10 training time: 6.37 seconds
# Privacy cost: (ε = 0.61, δ = 7.000000000000001e-09)
#   0%|          | 0/94 [00:00<?, ?it/s]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1830: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)
# 100%|██████████| 94/94 [00:04<00:00, 19.15it/s]
# /usr/local/lib/python3.11/dist-packages/opacus/accountants/analysis/rdp.py:332: UserWarning: Optimal order is the largest alpha. Please consider expanding the range of alphas to get a tighter privacy bound.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/opacus/accountants/analysis/prv/prvs.py:50: RuntimeWarning: invalid value encountered in log
#   z = np.log((np.exp(t) + q - 1) / q)
# Epoch 11 train loss: 0.8148, val loss: 0.7575
# Epoch 11 training time: 5.99 seconds
# Privacy cost: (ε = 0.64, δ = 7.000000000000001e-09)
#   0%|          | 0/94 [00:00<?, ?it/s]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1830: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)
# 100%|██████████| 94/94 [00:04<00:00, 20.72it/s]
# Epoch 12 train loss: 0.8151, val loss: 0.8106
# Epoch 12 training time: 5.29 seconds
# /usr/local/lib/python3.11/dist-packages/opacus/accountants/analysis/rdp.py:332: UserWarning: Optimal order is the largest alpha. Please consider expanding the range of alphas to get a tighter privacy bound.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/opacus/accountants/analysis/prv/prvs.py:50: RuntimeWarning: invalid value encountered in log
#   z = np.log((np.exp(t) + q - 1) / q)
# Privacy cost: (ε = 0.67, δ = 7.000000000000001e-09)
#   0%|          | 0/94 [00:00<?, ?it/s]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1830: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)
# 100%|██████████| 94/94 [00:05<00:00, 17.48it/s]
# /usr/local/lib/python3.11/dist-packages/opacus/accountants/analysis/rdp.py:332: UserWarning: Optimal order is the largest alpha. Please consider expanding the range of alphas to get a tighter privacy bound.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/opacus/accountants/analysis/prv/prvs.py:50: RuntimeWarning: invalid value encountered in log
#   z = np.log((np.exp(t) + q - 1) / q)
# Epoch 13 train loss: 0.8359, val loss: 0.7906
# Epoch 13 training time: 6.14 seconds
# Privacy cost: (ε = 0.70, δ = 7.000000000000001e-09)
#   0%|          | 0/94 [00:00<?, ?it/s]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1830: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)
# 100%|██████████| 94/94 [00:05<00:00, 18.19it/s]
# /usr/local/lib/python3.11/dist-packages/opacus/accountants/analysis/rdp.py:332: UserWarning: Optimal order is the largest alpha. Please consider expanding the range of alphas to get a tighter privacy bound.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/opacus/accountants/analysis/prv/prvs.py:50: RuntimeWarning: invalid value encountered in log
#   z = np.log((np.exp(t) + q - 1) / q)
# Epoch 14 train loss: 0.8771, val loss: 0.8354
# Epoch 14 training time: 6.29 seconds
# Privacy cost: (ε = 0.72, δ = 7.000000000000001e-09)
#   0%|          | 0/94 [00:00<?, ?it/s]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1830: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)
# 100%|██████████| 94/94 [00:04<00:00, 20.80it/s]
# Epoch 15 train loss: 0.8715, val loss: 0.8195
# Epoch 15 training time: 5.31 seconds
# /usr/local/lib/python3.11/dist-packages/opacus/accountants/analysis/rdp.py:332: UserWarning: Optimal order is the largest alpha. Please consider expanding the range of alphas to get a tighter privacy bound.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/opacus/accountants/analysis/prv/prvs.py:50: RuntimeWarning: invalid value encountered in log
#   z = np.log((np.exp(t) + q - 1) / q)
# Privacy cost: (ε = 0.75, δ = 7.000000000000001e-09)
#   0%|          | 0/94 [00:00<?, ?it/s]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1830: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)
# 100%|██████████| 94/94 [00:05<00:00, 16.29it/s]
# /usr/local/lib/python3.11/dist-packages/opacus/accountants/analysis/rdp.py:332: UserWarning: Optimal order is the largest alpha. Please consider expanding the range of alphas to get a tighter privacy bound.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/opacus/accountants/analysis/prv/prvs.py:50: RuntimeWarning: invalid value encountered in log
#   z = np.log((np.exp(t) + q - 1) / q)
# Epoch 16 train loss: 0.8718, val loss: 0.8086
# Epoch 16 training time: 6.54 seconds
# Privacy cost: (ε = 0.77, δ = 7.000000000000001e-09)
#   0%|          | 0/94 [00:00<?, ?it/s]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1830: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)
# 100%|██████████| 94/94 [00:05<00:00, 17.34it/s]
# /usr/local/lib/python3.11/dist-packages/opacus/accountants/analysis/rdp.py:332: UserWarning: Optimal order is the largest alpha. Please consider expanding the range of alphas to get a tighter privacy bound.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/opacus/accountants/analysis/prv/prvs.py:50: RuntimeWarning: invalid value encountered in log
#   z = np.log((np.exp(t) + q - 1) / q)
# Epoch 17 train loss: 0.8890, val loss: 0.8311
# Epoch 17 training time: 6.34 seconds
# Privacy cost: (ε = 0.80, δ = 7.000000000000001e-09)
#   0%|          | 0/94 [00:00<?, ?it/s]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1830: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)
# 100%|██████████| 94/94 [00:04<00:00, 20.38it/s]
# /usr/local/lib/python3.11/dist-packages/opacus/accountants/analysis/rdp.py:332: UserWarning: Optimal order is the largest alpha. Please consider expanding the range of alphas to get a tighter privacy bound.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/opacus/accountants/analysis/prv/prvs.py:50: RuntimeWarning: invalid value encountered in log
#   z = np.log((np.exp(t) + q - 1) / q)
# Epoch 18 train loss: 0.8225, val loss: 0.7556
# Epoch 18 training time: 5.39 seconds
# Privacy cost: (ε = 0.82, δ = 7.000000000000001e-09)
#   0%|          | 0/94 [00:00<?, ?it/s]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1830: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)
# 100%|██████████| 94/94 [00:04<00:00, 19.30it/s]
# /usr/local/lib/python3.11/dist-packages/opacus/accountants/analysis/rdp.py:332: UserWarning: Optimal order is the largest alpha. Please consider expanding the range of alphas to get a tighter privacy bound.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/opacus/accountants/analysis/prv/prvs.py:50: RuntimeWarning: invalid value encountered in log
#   z = np.log((np.exp(t) + q - 1) / q)
# Epoch 19 train loss: 0.8199, val loss: 0.8242
# Epoch 19 training time: 5.67 seconds
# Privacy cost: (ε = 0.84, δ = 7.000000000000001e-09)
#   0%|          | 0/94 [00:00<?, ?it/s]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1830: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)
# 100%|██████████| 94/94 [00:05<00:00, 16.59it/s]
# /usr/local/lib/python3.11/dist-packages/opacus/accountants/analysis/rdp.py:332: UserWarning: Optimal order is the largest alpha. Please consider expanding the range of alphas to get a tighter privacy bound.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/opacus/accountants/analysis/prv/prvs.py:50: RuntimeWarning: invalid value encountered in log
#   z = np.log((np.exp(t) + q - 1) / q)
# Epoch 20 train loss: 0.8310, val loss: 0.8332
# Epoch 20 training time: 6.44 seconds
# Privacy cost: (ε = 0.87, δ = 7.000000000000001e-09)
#   0%|          | 0/94 [00:00<?, ?it/s]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1830: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)
# 100%|██████████| 94/94 [00:04<00:00, 20.22it/s]
# /usr/local/lib/python3.11/dist-packages/opacus/accountants/analysis/rdp.py:332: UserWarning: Optimal order is the largest alpha. Please consider expanding the range of alphas to get a tighter privacy bound.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/opacus/accountants/analysis/prv/prvs.py:50: RuntimeWarning: invalid value encountered in log
#   z = np.log((np.exp(t) + q - 1) / q)
# Epoch 21 train loss: 0.8061, val loss: 0.7943
# Epoch 21 training time: 5.43 seconds
# Privacy cost: (ε = 0.89, δ = 7.000000000000001e-09)
#   0%|          | 0/94 [00:00<?, ?it/s]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1830: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)
# 100%|██████████| 94/94 [00:04<00:00, 19.64it/s]
# /usr/local/lib/python3.11/dist-packages/opacus/accountants/analysis/rdp.py:332: UserWarning: Optimal order is the largest alpha. Please consider expanding the range of alphas to get a tighter privacy bound.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/opacus/accountants/analysis/prv/prvs.py:50: RuntimeWarning: invalid value encountered in log
#   z = np.log((np.exp(t) + q - 1) / q)
# Epoch 22 train loss: 0.8412, val loss: 0.8146
# Epoch 22 training time: 5.60 seconds
# Privacy cost: (ε = 0.91, δ = 7.000000000000001e-09)
#   0%|          | 0/94 [00:00<?, ?it/s]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1830: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)
# 100%|██████████| 94/94 [00:05<00:00, 16.64it/s]
# /usr/local/lib/python3.11/dist-packages/opacus/accountants/analysis/rdp.py:332: UserWarning: Optimal order is the largest alpha. Please consider expanding the range of alphas to get a tighter privacy bound.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/opacus/accountants/analysis/prv/prvs.py:50: RuntimeWarning: invalid value encountered in log
#   z = np.log((np.exp(t) + q - 1) / q)
# Epoch 23 train loss: 0.8683, val loss: 0.8086
# Epoch 23 training time: 6.42 seconds
# Privacy cost: (ε = 0.93, δ = 7.000000000000001e-09)
#   0%|          | 0/94 [00:00<?, ?it/s]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1830: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)
# 100%|██████████| 94/94 [00:04<00:00, 19.52it/s]
# /usr/local/lib/python3.11/dist-packages/opacus/accountants/analysis/rdp.py:332: UserWarning: Optimal order is the largest alpha. Please consider expanding the range of alphas to get a tighter privacy bound.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/opacus/accountants/analysis/prv/prvs.py:50: RuntimeWarning: invalid value encountered in log
#   z = np.log((np.exp(t) + q - 1) / q)
# Epoch 24 train loss: 0.8299, val loss: 0.8861
# Epoch 24 training time: 5.91 seconds
# Privacy cost: (ε = 0.95, δ = 7.000000000000001e-09)
#   0%|          | 0/94 [00:00<?, ?it/s]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1830: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)
# 100%|██████████| 94/94 [00:04<00:00, 20.27it/s]
# Epoch 25 train loss: 0.8604, val loss: 0.8667
# Epoch 25 training time: 5.40 seconds
# /usr/local/lib/python3.11/dist-packages/opacus/accountants/analysis/rdp.py:332: UserWarning: Optimal order is the largest alpha. Please consider expanding the range of alphas to get a tighter privacy bound.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/opacus/accountants/analysis/prv/prvs.py:50: RuntimeWarning: invalid value encountered in log
#   z = np.log((np.exp(t) + q - 1) / q)
# Privacy cost: (ε = 0.97, δ = 7.000000000000001e-09)
#   0%|          | 0/94 [00:00<?, ?it/s]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1830: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)
# 100%|██████████| 94/94 [00:05<00:00, 17.11it/s]
# /usr/local/lib/python3.11/dist-packages/opacus/accountants/analysis/rdp.py:332: UserWarning: Optimal order is the largest alpha. Please consider expanding the range of alphas to get a tighter privacy bound.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/opacus/accountants/analysis/prv/prvs.py:50: RuntimeWarning: invalid value encountered in log
#   z = np.log((np.exp(t) + q - 1) / q)
# Epoch 26 train loss: 0.8796, val loss: 0.9137
# Epoch 26 training time: 6.28 seconds
# Privacy cost: (ε = 0.99, δ = 7.000000000000001e-09)
#   0%|          | 0/94 [00:00<?, ?it/s]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1830: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)
# 100%|██████████| 94/94 [00:05<00:00, 18.44it/s]
# /usr/local/lib/python3.11/dist-packages/opacus/accountants/analysis/rdp.py:332: UserWarning: Optimal order is the largest alpha. Please consider expanding the range of alphas to get a tighter privacy bound.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/opacus/accountants/analysis/prv/prvs.py:50: RuntimeWarning: invalid value encountered in log
#   z = np.log((np.exp(t) + q - 1) / q)
# Epoch 27 train loss: 0.8586, val loss: 0.9167
# Epoch 27 training time: 6.15 seconds
# Privacy cost: (ε = 1.01, δ = 7.000000000000001e-09)
#   0%|          | 0/94 [00:00<?, ?it/s]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1830: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)
# 100%|██████████| 94/94 [00:04<00:00, 20.29it/s]
# /usr/local/lib/python3.11/dist-packages/opacus/accountants/analysis/rdp.py:332: UserWarning: Optimal order is the largest alpha. Please consider expanding the range of alphas to get a tighter privacy bound.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/opacus/accountants/analysis/prv/prvs.py:50: RuntimeWarning: invalid value encountered in log
#   z = np.log((np.exp(t) + q - 1) / q)
# Epoch 28 train loss: 0.8671, val loss: 0.8673
# Epoch 28 training time: 5.40 seconds
# Privacy cost: (ε = 1.03, δ = 7.000000000000001e-09)
#   0%|          | 0/94 [00:00<?, ?it/s]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1830: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)
# 100%|██████████| 94/94 [00:05<00:00, 17.97it/s]
# /usr/local/lib/python3.11/dist-packages/opacus/accountants/analysis/rdp.py:332: UserWarning: Optimal order is the largest alpha. Please consider expanding the range of alphas to get a tighter privacy bound.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/opacus/accountants/analysis/prv/prvs.py:50: RuntimeWarning: invalid value encountered in log
#   z = np.log((np.exp(t) + q - 1) / q)
# Epoch 29 train loss: 0.8632, val loss: 0.7781
# Epoch 29 training time: 6.00 seconds
# Privacy cost: (ε = 1.05, δ = 7.000000000000001e-09)
#   0%|          | 0/94 [00:00<?, ?it/s]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1830: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)
# 100%|██████████| 94/94 [00:05<00:00, 17.80it/s]
# /usr/local/lib/python3.11/dist-packages/opacus/accountants/analysis/rdp.py:332: UserWarning: Optimal order is the largest alpha. Please consider expanding the range of alphas to get a tighter privacy bound.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/opacus/accountants/analysis/prv/prvs.py:50: RuntimeWarning: invalid value encountered in log
#   z = np.log((np.exp(t) + q - 1) / q)
# Epoch 30 train loss: 0.8274, val loss: 0.7833
# Epoch 30 training time: 6.39 seconds
# Privacy cost: (ε = 1.07, δ = 7.000000000000001e-09)
#   0%|          | 0/94 [00:00<?, ?it/s]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1830: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)
# 100%|██████████| 94/94 [00:04<00:00, 20.44it/s]
# /usr/local/lib/python3.11/dist-packages/opacus/accountants/analysis/rdp.py:332: UserWarning: Optimal order is the largest alpha. Please consider expanding the range of alphas to get a tighter privacy bound.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/opacus/accountants/analysis/prv/prvs.py:50: RuntimeWarning: invalid value encountered in log
#   z = np.log((np.exp(t) + q - 1) / q)
# Epoch 31 train loss: 0.8551, val loss: 0.8677
# Epoch 31 training time: 5.39 seconds
# Privacy cost: (ε = 1.08, δ = 7.000000000000001e-09)
#   0%|          | 0/94 [00:00<?, ?it/s]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1830: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)
# 100%|██████████| 94/94 [00:05<00:00, 18.29it/s]
# /usr/local/lib/python3.11/dist-packages/opacus/accountants/analysis/rdp.py:332: UserWarning: Optimal order is the largest alpha. Please consider expanding the range of alphas to get a tighter privacy bound.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/opacus/accountants/analysis/prv/prvs.py:50: RuntimeWarning: invalid value encountered in log
#   z = np.log((np.exp(t) + q - 1) / q)
# Epoch 32 train loss: 0.9005, val loss: 0.8878
# Epoch 32 training time: 5.94 seconds
# Privacy cost: (ε = 1.10, δ = 7.000000000000001e-09)
#   0%|          | 0/94 [00:00<?, ?it/s]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1830: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)
# 100%|██████████| 94/94 [00:05<00:00, 16.84it/s]
# /usr/local/lib/python3.11/dist-packages/opacus/accountants/analysis/rdp.py:332: UserWarning: Optimal order is the largest alpha. Please consider expanding the range of alphas to get a tighter privacy bound.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/opacus/accountants/analysis/prv/prvs.py:50: RuntimeWarning: invalid value encountered in log
#   z = np.log((np.exp(t) + q - 1) / q)
# Epoch 33 train loss: 0.8871, val loss: 0.8888
# Epoch 33 training time: 6.35 seconds
# Privacy cost: (ε = 1.12, δ = 7.000000000000001e-09)
#   0%|          | 0/94 [00:00<?, ?it/s]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1830: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)
# 100%|██████████| 94/94 [00:04<00:00, 20.41it/s]
# /usr/local/lib/python3.11/dist-packages/opacus/accountants/analysis/rdp.py:332: UserWarning: Optimal order is the largest alpha. Please consider expanding the range of alphas to get a tighter privacy bound.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/opacus/accountants/analysis/prv/prvs.py:50: RuntimeWarning: invalid value encountered in log
#   z = np.log((np.exp(t) + q - 1) / q)
# Epoch 34 train loss: 0.9678, val loss: 0.9396
# Epoch 34 training time: 5.34 seconds
# Privacy cost: (ε = 1.14, δ = 7.000000000000001e-09)
#   0%|          | 0/94 [00:00<?, ?it/s]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1830: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)
# 100%|██████████| 94/94 [00:04<00:00, 20.64it/s]
# /usr/local/lib/python3.11/dist-packages/opacus/accountants/analysis/rdp.py:332: UserWarning: Optimal order is the largest alpha. Please consider expanding the range of alphas to get a tighter privacy bound.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/opacus/accountants/analysis/prv/prvs.py:50: RuntimeWarning: invalid value encountered in log
#   z = np.log((np.exp(t) + q - 1) / q)
# Epoch 35 train loss: 0.9518, val loss: 0.9266
# Epoch 35 training time: 5.34 seconds
# Privacy cost: (ε = 1.15, δ = 7.000000000000001e-09)
#   0%|          | 0/94 [00:00<?, ?it/s]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1830: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)
# 100%|██████████| 94/94 [00:05<00:00, 16.63it/s]
# /usr/local/lib/python3.11/dist-packages/opacus/accountants/analysis/rdp.py:332: UserWarning: Optimal order is the largest alpha. Please consider expanding the range of alphas to get a tighter privacy bound.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/opacus/accountants/analysis/prv/prvs.py:50: RuntimeWarning: invalid value encountered in log
#   z = np.log((np.exp(t) + q - 1) / q)
# Epoch 36 train loss: 0.9063, val loss: 0.8367
# Epoch 36 training time: 6.41 seconds
# Privacy cost: (ε = 1.17, δ = 7.000000000000001e-09)
#   0%|          | 0/94 [00:00<?, ?it/s]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1830: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)
# 100%|██████████| 94/94 [00:04<00:00, 19.94it/s]
# /usr/local/lib/python3.11/dist-packages/opacus/accountants/analysis/rdp.py:332: UserWarning: Optimal order is the largest alpha. Please consider expanding the range of alphas to get a tighter privacy bound.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/opacus/accountants/analysis/prv/prvs.py:50: RuntimeWarning: invalid value encountered in log
#   z = np.log((np.exp(t) + q - 1) / q)
# Epoch 37 train loss: 0.8788, val loss: 0.8742
# Epoch 37 training time: 5.61 seconds
# Privacy cost: (ε = 1.19, δ = 7.000000000000001e-09)
#   0%|          | 0/94 [00:00<?, ?it/s]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1830: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)
# 100%|██████████| 94/94 [00:04<00:00, 20.85it/s]
# /usr/local/lib/python3.11/dist-packages/opacus/accountants/analysis/rdp.py:332: UserWarning: Optimal order is the largest alpha. Please consider expanding the range of alphas to get a tighter privacy bound.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/opacus/accountants/analysis/prv/prvs.py:50: RuntimeWarning: invalid value encountered in log
#   z = np.log((np.exp(t) + q - 1) / q)
# Epoch 38 train loss: 0.9095, val loss: 0.9287
# Epoch 38 training time: 5.31 seconds
# Privacy cost: (ε = 1.20, δ = 7.000000000000001e-09)
#   0%|          | 0/94 [00:00<?, ?it/s]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1830: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)
# 100%|██████████| 94/94 [00:05<00:00, 16.53it/s]
# /usr/local/lib/python3.11/dist-packages/opacus/accountants/analysis/rdp.py:332: UserWarning: Optimal order is the largest alpha. Please consider expanding the range of alphas to get a tighter privacy bound.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/opacus/accountants/analysis/prv/prvs.py:50: RuntimeWarning: invalid value encountered in log
#   z = np.log((np.exp(t) + q - 1) / q)
# Epoch 39 train loss: 0.9457, val loss: 0.9667
# Epoch 39 training time: 6.50 seconds
# Privacy cost: (ε = 1.22, δ = 7.000000000000001e-09)
#   0%|          | 0/94 [00:00<?, ?it/s]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1830: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)
# 100%|██████████| 94/94 [00:04<00:00, 19.72it/s]
# /usr/local/lib/python3.11/dist-packages/opacus/accountants/analysis/rdp.py:332: UserWarning: Optimal order is the largest alpha. Please consider expanding the range of alphas to get a tighter privacy bound.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/opacus/accountants/analysis/prv/prvs.py:50: RuntimeWarning: invalid value encountered in log
#   z = np.log((np.exp(t) + q - 1) / q)
# Epoch 40 train loss: 0.9388, val loss: 0.8413
# Epoch 40 training time: 5.93 seconds
# Privacy cost: (ε = 1.24, δ = 7.000000000000001e-09)
#   0%|          | 0/94 [00:00<?, ?it/s]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1830: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)
# 100%|██████████| 94/94 [00:04<00:00, 19.62it/s]
# Epoch 41 train loss: 0.8920, val loss: 0.8873
# Epoch 41 training time: 5.57 seconds
# /usr/local/lib/python3.11/dist-packages/opacus/accountants/analysis/rdp.py:332: UserWarning: Optimal order is the largest alpha. Please consider expanding the range of alphas to get a tighter privacy bound.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/opacus/accountants/analysis/prv/prvs.py:50: RuntimeWarning: invalid value encountered in log
#   z = np.log((np.exp(t) + q - 1) / q)
# Privacy cost: (ε = 1.25, δ = 7.000000000000001e-09)
#   0%|          | 0/94 [00:00<?, ?it/s]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1830: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)
# 100%|██████████| 94/94 [00:05<00:00, 16.81it/s]
# /usr/local/lib/python3.11/dist-packages/opacus/accountants/analysis/rdp.py:332: UserWarning: Optimal order is the largest alpha. Please consider expanding the range of alphas to get a tighter privacy bound.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/opacus/accountants/analysis/prv/prvs.py:50: RuntimeWarning: invalid value encountered in log
#   z = np.log((np.exp(t) + q - 1) / q)
# Epoch 42 train loss: 0.9050, val loss: 0.8534
# Epoch 42 training time: 6.35 seconds
# Privacy cost: (ε = 1.27, δ = 7.000000000000001e-09)
# Validation metric improved from 0.0000 to 0.7815
# Saved best model to model_init_0_best_epoch_41_auc_0.9541_acc_0.7815.pth
#   0%|          | 0/94 [00:00<?, ?it/s]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1830: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)
# 100%|██████████| 94/94 [00:05<00:00, 17.30it/s]
# /usr/local/lib/python3.11/dist-packages/opacus/accountants/analysis/rdp.py:332: UserWarning: Optimal order is the largest alpha. Please consider expanding the range of alphas to get a tighter privacy bound.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/opacus/accountants/analysis/prv/prvs.py:50: RuntimeWarning: invalid value encountered in log
#   z = np.log((np.exp(t) + q - 1) / q)
# Epoch 43 train loss: 0.8693, val loss: 0.8609
# Epoch 43 training time: 6.61 seconds
# Privacy cost: (ε = 1.28, δ = 7.000000000000001e-09)
# No improvement for 1 epochs
#   0%|          | 0/94 [00:00<?, ?it/s]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1830: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)
# 100%|██████████| 94/94 [00:04<00:00, 19.24it/s]
# Epoch 44 train loss: 0.8646, val loss: 0.9404
# Epoch 44 training time: 5.67 seconds
# /usr/local/lib/python3.11/dist-packages/opacus/accountants/analysis/rdp.py:332: UserWarning: Optimal order is the largest alpha. Please consider expanding the range of alphas to get a tighter privacy bound.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/opacus/accountants/analysis/prv/prvs.py:50: RuntimeWarning: invalid value encountered in log
#   z = np.log((np.exp(t) + q - 1) / q)
# Privacy cost: (ε = 1.30, δ = 7.000000000000001e-09)
# No improvement for 2 epochs
#   0%|          | 0/94 [00:00<?, ?it/s]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1830: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)
# 100%|██████████| 94/94 [00:04<00:00, 18.97it/s]
# /usr/local/lib/python3.11/dist-packages/opacus/accountants/analysis/rdp.py:332: UserWarning: Optimal order is the largest alpha. Please consider expanding the range of alphas to get a tighter privacy bound.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/opacus/accountants/analysis/prv/prvs.py:50: RuntimeWarning: invalid value encountered in log
#   z = np.log((np.exp(t) + q - 1) / q)
# Epoch 45 train loss: 0.9407, val loss: 0.9343
# Epoch 45 training time: 5.75 seconds
# Privacy cost: (ε = 1.31, δ = 7.000000000000001e-09)
# No improvement for 3 epochs
#   0%|          | 0/94 [00:00<?, ?it/s]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1830: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)
# 100%|██████████| 94/94 [00:05<00:00, 16.83it/s]
# Epoch 46 train loss: 0.9258, val loss: 0.9136
# Epoch 46 training time: 6.35 seconds
# /usr/local/lib/python3.11/dist-packages/opacus/accountants/analysis/rdp.py:332: UserWarning: Optimal order is the largest alpha. Please consider expanding the range of alphas to get a tighter privacy bound.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/opacus/accountants/analysis/prv/prvs.py:50: RuntimeWarning: invalid value encountered in log
#   z = np.log((np.exp(t) + q - 1) / q)
# Privacy cost: (ε = 1.33, δ = 7.000000000000001e-09)
# No improvement for 4 epochs
# ...
#   0%|          | 0/94 [00:00<?, ?it/s]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1830: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)
# 100%|██████████| 94/94 [00:04<00:00, 20.39it/s]
# /usr/local/lib/python3.11/dist-packages/opacus/accountants/analysis/rdp.py:332: UserWarning: Optimal order is the largest alpha. Please consider expanding the range of alphas to get a tighter privacy bound.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/opacus/accountants/analysis/prv/prvs.py:50: RuntimeWarning: invalid value encountered in log
#   z = np.log((np.exp(t) + q - 1) / q)
# Epoch 48 train loss: 1.0604, val loss: 1.1414
# Epoch 48 training time: 5.40 seconds
# Privacy cost: (ε = 1.36, δ = 7.000000000000001e-09)
# No improvement for 5 epochs
#   0%|          | 0/94 [00:00<?, ?it/s]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1830: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)
# 100%|██████████| 94/94 [00:05<00:00, 16.82it/s]
# /usr/local/lib/python3.11/dist-packages/opacus/accountants/analysis/rdp.py:332: UserWarning: Optimal order is the largest alpha. Please consider expanding the range of alphas to get a tighter privacy bound.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/opacus/accountants/analysis/prv/prvs.py:50: RuntimeWarning: invalid value encountered in log
#   z = np.log((np.exp(t) + q - 1) / q)
# Epoch 49 train loss: 1.1768, val loss: 1.1539
# Epoch 49 training time: 6.35 seconds
# Privacy cost: (ε = 1.37, δ = 7.000000000000001e-09)
# No improvement for 6 epochs
#   0%|          | 0/94 [00:00<?, ?it/s]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1830: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)
# 100%|██████████| 94/94 [00:04<00:00, 20.47it/s]
# /usr/local/lib/python3.11/dist-packages/opacus/accountants/analysis/rdp.py:332: UserWarning: Optimal order is the largest alpha. Please consider expanding the range of alphas to get a tighter privacy bound.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/opacus/accountants/analysis/prv/prvs.py:50: RuntimeWarning: invalid value encountered in log
#   z = np.log((np.exp(t) + q - 1) / q)
# Epoch 50 train loss: 1.1249, val loss: 1.1276
# Epoch 50 training time: 5.35 seconds
# Privacy cost: (ε = 1.39, δ = 7.000000000000001e-09)
# No improvement for 7 epochs
#   0%|          | 0/94 [00:00<?, ?it/s]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1830: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)
# 100%|██████████| 94/94 [00:05<00:00, 16.62it/s]
# /usr/local/lib/python3.11/dist-packages/opacus/accountants/analysis/rdp.py:332: UserWarning: Optimal order is the largest alpha. Please consider expanding the range of alphas to get a tighter privacy bound.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/opacus/accountants/analysis/prv/prvs.py:50: RuntimeWarning: invalid value encountered in log
#   z = np.log((np.exp(t) + q - 1) / q)
# Epoch 51 train loss: 1.0911, val loss: 1.1287
# Epoch 51 training time: 6.43 seconds
# Privacy cost: (ε = 1.40, δ = 7.000000000000001e-09)
# No improvement for 8 epochs
#   0%|          | 0/94 [00:00<?, ?it/s]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1830: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)
# 100%|██████████| 94/94 [00:04<00:00, 20.32it/s]
# /usr/local/lib/python3.11/dist-packages/opacus/accountants/analysis/rdp.py:332: UserWarning: Optimal order is the largest alpha. Please consider expanding the range of alphas to get a tighter privacy bound.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/opacus/accountants/analysis/prv/prvs.py:50: RuntimeWarning: invalid value encountered in log
#   z = np.log((np.exp(t) + q - 1) / q)
# Epoch 52 train loss: 1.1123, val loss: 1.0919
# Epoch 52 training time: 5.39 seconds
# Privacy cost: (ε = 1.42, δ = 7.000000000000001e-09)
# Validation metric improved from 0.7471 to 0.7593
# Saved best model to model_init_2_best_epoch_51_auc_0.9444_acc_0.7593.pth
#   0%|          | 0/94 [00:00<?, ?it/s]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1830: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)
# 100%|██████████| 94/94 [00:05<00:00, 17.02it/s]
# /usr/local/lib/python3.11/dist-packages/opacus/accountants/analysis/rdp.py:332: UserWarning: Optimal order is the largest alpha. Please consider expanding the range of alphas to get a tighter privacy bound.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/opacus/accountants/analysis/prv/prvs.py:50: RuntimeWarning: invalid value encountered in log
#   z = np.log((np.exp(t) + q - 1) / q)
# Epoch 53 train loss: 1.1221, val loss: 1.0709
# Epoch 53 training time: 6.58 seconds
# Privacy cost: (ε = 1.43, δ = 7.000000000000001e-09)
# No improvement for 1 epochs
#   0%|          | 0/94 [00:00<?, ?it/s]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1830: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)
# 100%|██████████| 94/94 [00:04<00:00, 20.08it/s]
# /usr/local/lib/python3.11/dist-packages/opacus/accountants/analysis/rdp.py:332: UserWarning: Optimal order is the largest alpha. Please consider expanding the range of alphas to get a tighter privacy bound.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/opacus/accountants/analysis/prv/prvs.py:50: RuntimeWarning: invalid value encountered in log
#   z = np.log((np.exp(t) + q - 1) / q)
# Epoch 54 train loss: 1.0996, val loss: 1.1244
# Epoch 54 training time: 5.46 seconds
# Privacy cost: (ε = 1.45, δ = 7.000000000000001e-09)
# No improvement for 2 epochs
#   0%|          | 0/94 [00:00<?, ?it/s]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1830: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)
# 100%|██████████| 94/94 [00:05<00:00, 18.38it/s]
# Epoch 55 train loss: 1.0785, val loss: 1.0108
# Epoch 55 training time: 6.13 seconds
# /usr/local/lib/python3.11/dist-packages/opacus/accountants/analysis/rdp.py:332: UserWarning: Optimal order is the largest alpha. Please consider expanding the range of alphas to get a tighter privacy bound.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/opacus/accountants/analysis/prv/prvs.py:50: RuntimeWarning: invalid value encountered in log
#   z = np.log((np.exp(t) + q - 1) / q)
# Privacy cost: (ε = 1.46, δ = 7.000000000000001e-09)
# No improvement for 3 epochs
#   0%|          | 0/94 [00:00<?, ?it/s]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1830: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)
# 100%|██████████| 94/94 [00:04<00:00, 19.32it/s]
# /usr/local/lib/python3.11/dist-packages/opacus/accountants/analysis/rdp.py:332: UserWarning: Optimal order is the largest alpha. Please consider expanding the range of alphas to get a tighter privacy bound.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/opacus/accountants/analysis/prv/prvs.py:50: RuntimeWarning: invalid value encountered in log
#   z = np.log((np.exp(t) + q - 1) / q)
# Epoch 56 train loss: 1.0388, val loss: 1.0072
# Epoch 56 training time: 5.62 seconds
# Privacy cost: (ε = 1.47, δ = 7.000000000000001e-09)
# No improvement for 4 epochs
#   0%|          | 0/94 [00:00<?, ?it/s]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1830: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)
# 100%|██████████| 94/94 [00:04<00:00, 20.01it/s]
# Epoch 57 train loss: 1.0415, val loss: 1.0334
# Epoch 57 training time: 5.69 seconds
# /usr/local/lib/python3.11/dist-packages/opacus/accountants/analysis/rdp.py:332: UserWarning: Optimal order is the largest alpha. Please consider expanding the range of alphas to get a tighter privacy bound.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/opacus/accountants/analysis/prv/prvs.py:50: RuntimeWarning: invalid value encountered in log
#   z = np.log((np.exp(t) + q - 1) / q)
# Privacy cost: (ε = 1.49, δ = 7.000000000000001e-09)
# No improvement for 5 epochs
#   0%|          | 0/94 [00:00<?, ?it/s]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1830: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)
# 100%|██████████| 94/94 [00:05<00:00, 17.18it/s]
# /usr/local/lib/python3.11/dist-packages/opacus/accountants/analysis/rdp.py:332: UserWarning: Optimal order is the largest alpha. Please consider expanding the range of alphas to get a tighter privacy bound.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/opacus/accountants/analysis/prv/prvs.py:50: RuntimeWarning: invalid value encountered in log
#   z = np.log((np.exp(t) + q - 1) / q)
# Epoch 58 train loss: 1.0607, val loss: 1.0507
# Epoch 58 training time: 6.24 seconds
# Privacy cost: (ε = 1.50, δ = 7.000000000000001e-09)
# No improvement for 6 epochs
#   0%|          | 0/94 [00:00<?, ?it/s]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1830: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)
# 100%|██████████| 94/94 [00:04<00:00, 20.16it/s]
# /usr/local/lib/python3.11/dist-packages/opacus/accountants/analysis/rdp.py:332: UserWarning: Optimal order is the largest alpha. Please consider expanding the range of alphas to get a tighter privacy bound.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/opacus/accountants/analysis/prv/prvs.py:50: RuntimeWarning: invalid value encountered in log
#   z = np.log((np.exp(t) + q - 1) / q)
# Epoch 59 train loss: 1.0312, val loss: 1.0200
# Epoch 59 training time: 5.43 seconds
# Privacy cost: (ε = 1.51, δ = 7.000000000000001e-09)
# No improvement for 7 epochs
#   0%|          | 0/94 [00:00<?, ?it/s]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1830: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)
# 100%|██████████| 94/94 [00:05<00:00, 16.56it/s]
# /usr/local/lib/python3.11/dist-packages/opacus/accountants/analysis/rdp.py:332: UserWarning: Optimal order is the largest alpha. Please consider expanding the range of alphas to get a tighter privacy bound.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/opacus/accountants/analysis/prv/prvs.py:50: RuntimeWarning: invalid value encountered in log
#   z = np.log((np.exp(t) + q - 1) / q)
# Epoch 60 train loss: 1.0585, val loss: 0.9809
# Epoch 60 training time: 6.45 seconds
# Privacy cost: (ε = 1.53, δ = 7.000000000000001e-09)
# No improvement for 8 epochs
#   0%|          | 0/94 [00:00<?, ?it/s]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1830: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)
# 100%|██████████| 94/94 [00:04<00:00, 20.08it/s]
# /usr/local/lib/python3.11/dist-packages/opacus/accountants/analysis/rdp.py:332: UserWarning: Optimal order is the largest alpha. Please consider expanding the range of alphas to get a tighter privacy bound.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/opacus/accountants/analysis/prv/prvs.py:50: RuntimeWarning: invalid value encountered in log
#   z = np.log((np.exp(t) + q - 1) / q)
# Epoch 61 train loss: 1.0131, val loss: 1.0008
# Epoch 61 training time: 5.46 seconds
# Privacy cost: (ε = 1.54, δ = 7.000000000000001e-09)
# No improvement for 9 epochs
#   0%|          | 0/94 [00:00<?, ?it/s]/usr/local/lib/python3.11/dist-packages/torch/nn/modules/module.py:1830: FutureWarning: Using a non-full backward hook when the forward contains multiple autograd Nodes is deprecated and will be removed in future versions. This hook will be missing some grad_input. Please use register_full_backward_hook to get the documented behavior.
#   self._maybe_warn_non_full_backward_hook(args, result, grad_fn)
# 100%|██████████| 94/94 [00:05<00:00, 16.09it/s]
# Epoch 62 train loss: 1.0019, val loss: 1.0047
# Epoch 62 training time: 6.64 seconds
# Privacy cost: (ε = 1.55, δ = 7.000000000000001e-09)
# No improvement for 10 epochs
# Early stopping at epoch 62
# --------------------------------
# Instance 2
# Best epoch: 52
# Best validation ACC: 0.7593
# Training time until best model: 303.46 seconds
# Total training time: 363.16 seconds
# /usr/local/lib/python3.11/dist-packages/opacus/accountants/analysis/rdp.py:332: UserWarning: Optimal order is the largest alpha. Please consider expanding the range of alphas to get a tighter privacy bound.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/opacus/accountants/analysis/prv/prvs.py:50: RuntimeWarning: invalid value encountered in log
#   z = np.log((np.exp(t) + q - 1) / q)

# %%
# the first trained model is shown
plt.plot(loss_curve_train, label='train')
plt.plot(loss_curve_val, label='val')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.savefig(f"Loss_vs_Epochs_C={C}_epsilon={EPSILON}_Batch_size_{BATCH_SIZE}_lr_{LR}.png", dpi=300)

# %%
# the first trained model is shown
plt.plot(auc_curve_train, label='train')
plt.plot(auc_curve_val, label='val')
plt.xlabel('Epoch')
plt.ylabel('AUC')
plt.legend()
plt.savefig(f"AUC_vs_Epochs_C={C}_epsilon={EPSILON}_Batch_size_{BATCH_SIZE}_lr_{LR}.png", dpi=300)

# %%
plt.plot(acc_curve_train, label='train')
plt.plot(acc_curve_val, label='val')
plt.xlabel('Epoch')
plt.ylabel('ACC')
plt.legend()
plt.savefig(f"ACC_vs_Epochs_C={C}_epsilon={EPSILON}_Batch_size_{BATCH_SIZE}_lr_{LR}.png", dpi=300)

# %% [markdown]
# ## Evaluation

# %%
print('==> Evaluating ...')
final_auc_train = []
final_acc_train = []

final_auc_test = []
final_acc_test = []

for i, model_path in enumerate(best_models):


    model = get_model(n_channels, n_classes)
    state_dict = torch.load(model_path)
    model.load_state_dict(state_dict)
    model.eval()

    metric_train = scores('train', model, info, data_flag, train_loader_at_eval, val_loader_at_eval, test_loader)
    final_auc_train.append(metric_train.AUC)
    final_acc_train.append(metric_train.ACC)

    metric_test = scores('test', model, info, data_flag, train_loader_at_eval, val_loader_at_eval, test_loader)
    final_auc_test.append(metric_test.AUC)
    final_acc_test.append(metric_test.ACC)

print("--------------------------------------------------")
print(f"Average stopping epoch: {np.mean(early_stop_epochs):.1f} ± {np.std(early_stop_epochs):.1f}")
print(f"Average training time: {np.mean(early_stop_times):.2f} ± {np.std(early_stop_times):.2f} seconds")
print(f"Average epoch time: {np.mean(av_epoch_time):.2f} ± {np.std(av_epoch_time):.2f} seconds")
print(f"Batch size:", BATCH_SIZE)
print(f"Learning rate:", LR)

print("--------------------------------------------------")
print(f"Clipping parameter: {C}")
print(f"Privacy parameters: {EPSILON, DELTA}")
print("--------------------------------------------------")
print(f"ACC (train): {np.mean(final_acc_train):.4f}  ± {np.std(final_acc_train):.4f}")
print(f"AUC (train): {np.mean(final_auc_train):.4f} ± {np.std(final_auc_train):.4f}")
print("--------------------------------------------------")
print(f"ACC (test): {np.mean(final_acc_test):.4f} ± {np.std(final_acc_test):.4f}")
print(f"AUC (test): {np.mean(final_auc_test):.4f} ± {np.std(final_auc_test):.4f}")
# Out:
# ==> Evaluating ...
# Using device: cuda
# Using device: cuda
# Using device: cuda
# --------------------------------------------------
# Average stopping epoch: 51.0 ± 7.0
# Average training time: 360.33 ± 41.05 seconds
# Average epoch time: 5.91 ± 0.48 seconds
# Batch size: 128
# Learning rate: 0.001
# --------------------------------------------------
# Clipping parameter: 0.1259
# Privacy parameters: (2, 7.000000000000001e-09)
# --------------------------------------------------
# ACC (train): 0.7754  ± 0.0226
# AUC (train): 0.9538 ± 0.0099
# --------------------------------------------------
# ACC (test): 0.7715 ± 0.0217
# AUC (test): 0.9522 ± 0.0103
